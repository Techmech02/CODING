# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("tips")
print(df.to_string())
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
sns.scatterplot(x="total_bill", y="tip", data=df)
plt.title("Scatterplot of Total Bill vs Tip",fontsize =30,color='red',fontweight ='bold',backgroundcolor = "yellow",stylecoor="italic")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 sns.scatterplot(x="total_bill", y="tip", data=df)
# ----> 2 plt.title("Scatterplot of Total Bill vs Tip",fontsize =30,color='red',fontweight ='bold',backgroundcolor = "yellow",stylecoor="italic")
#
# File e:\Python\Lib\site-packages\matplotlib\pyplot.py:4383, in title(label, fontdict, loc, pad, y, **kwargs)
#    4373 @_copy_docstring_and_deprecators(Axes.set_title)
#    4374 def title(
#    4375     label: str,
#    (...)   4381     **kwargs,
#    4382 ) -> Text:
# -> 4383     return gca().set_title(label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#
# File e:\Python\Lib\site-packages\matplotlib\axes\_axes.py:201, in Axes.set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     199 if fontdict is not None:
#     200     title.update(fontdict)
# --> 201 title._internal_update(kwargs)
# ...

# %%
sns.kdeplot(df["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
"""sns
categorical plot --- catplot
relationship plot ---replot"""
sns.relplot(x=df["total_bill"],y=df["tip"],data=df)

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="reg")

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="hex")

# %%
sns.pairplot(df)

# %% [markdown]
# outliers -- remove ya transform

# %%
sns.barplot(df[""]
# Out:
#   Cell In[14], line 1
#     sns.barplot(df[""]
#                       ^
# _IncompleteInputError: incomplete input

# %%
q1= df["total_bill"].quantile(0.25)
q3= df["total_bill"].quantile(0.25)
iqr=q3-q1

l_bound=q3 -1.5*iqr
u_bound=q3 +1.5*iqr

df[df["total_bill"]>u_bound]
df[df["total_bill"]<l_bound]

df = df[(df["total_bill"]>l_bound) &( df["total_bill"]<u_bound)]
sns.boxplot(df["total_bill"])
# Out:
# <Axes: >

# %%
df=pd.read_csv("data.csv")
print(df)
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyoty        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
cat_col = df.select_dtypes(include="O")
cat_col.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
num_col = df.select_dtypes(exclude="O")
num_col.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
## feature selection ---imp step
df.drop(labels="model")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 ## feature selection ---imp step
# ----> 2 df.drop(labels="model")
#
# File e:\Python\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
##encoding --char ---num
## 1 label encoding
## 2 --- one shot encoding

# %%
##one hot encoding
pd.get_dummies(cat_col).astype(int).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 ##one hot encoding
# ----> 2 pd.get_dummies(cat_col).astype(int).head()
#
# File e:\Python\Lib\site-packages\pandas\core\reshape\encoding.py:224, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     214         dummy = _get_dummies_1d(
#     215             col[1],
#     216             prefix=pre,
#    (...)    221             dtype=dtype,
#     222         )
#     223         with_dummies.append(dummy)
# --> 224     result = concat(with_dummies, axis=1)
#     225 else:
#     226     result = _get_dummies_1d(
#     227         data,
#     228         prefix,
#    (...)    233         dtype=dtype,
#     234     )
#
# ...

# %%
##label encoding
cat_col.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
dt={
    "first owner" : 1,
    "second owner" : 2,
    "third owner" : 3,
    "fourth or more owner": 4
 }
cat_col =cat_col["owner"].map(dt)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\Python\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'owner'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 7
#       1 dt={
#       2     "first owner" : 1,
#       3     "second owner" : 2,
# ...

# %%
{i: key for key ,i in enumerate(list(cat_col["brand"].unique()))}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\Python\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'brand'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 {i: key for key ,i in enumerate(list(cat_col["brand"].unique()))}
#
# ...

# %%
sns.heatmap(metrix,annot=True)
plt.show()
