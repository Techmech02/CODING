# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

sns.displot([0,1,2,3,4,5],kind="kde")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 6
#       3 import numpy as np
#       5 sns.displot([0,1,2,3,4,5],kind="kde")
# ----> 6 plt.show()
#
# File e:\Python\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
from numpy import random
x=random.normal(1,2,size=(2,3))
print(x)
# Out:
# [[-1.96159114  1.5924029   7.50203414]
#  [ 0.55502625  1.11287236 -0.9920967 ]]

# %%
sns.displot(random.normal(size=1000),kind="kde")

# %%
sns.displot(random.binomial(n=10,p=0.5,size=1000),fill=True)

# %%
random_dist={
    "normal":sns.displot(random.normal(size=1000)),
    
    "poisson":sns.displot(random.poisson(lma=2,size=1000)),
    
    "exponential":sns.displot(random.exponential(scale=2,size=50)),
    
    "chisquared":sns.displot(random.chisquare(df=3.142856,size=100))
    

}

# %%
x=np.linspace(0,10,100)
plt.figure(figsize=(10,5))
plt.subplot(2,2,1)

plt.plot(x,np.sin(x))
plt.title("sin(X)")

plt.subplot(2,2,3)
plt.plot(x,np.cos(X))
plt.title("cos(x)")

plt.subplot(2,2,4)
plt.plot(x,np.tan(X))
plt.title("tan(x)")

plt.subplot(2,2,5)
plt.plot(x,np.exp(X))
plt.title("exp(x)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 x=np.linspace(0,10,100)
# ----> 2 plt.figure(figsize=(10,5))
#       3 plt.subplot(2,2,1)
#       5 plt.plot(x,np.sin(x))
#
# TypeError: 'module' object is not callable
