# %%
#Decision TREE
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

df=pd.read_csv("decisoncomedydata.csv")

df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

d={
    'UK' : 0,'USA': 1,'N': 2
}
df['Nationality'] =df['Nationality'].map(d)

features =['Age','Experience','Rank','Nationality']
X=df[features]
y=df['Go']

dtree =DecisionTreeClassifier()
dtree=dtree.fit(X,y)
tree.plot_tree(dtree,feature_names=features)
# Out:
# [Text(0.5555555555555556, 0.875, 'Experience <= 9.5\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(0.3333333333333333, 0.625, 'Rank <= 6.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.4444444444444444, 0.75, 'True  '),
#  Text(0.2222222222222222, 0.375, 'Rank <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1111111111111111, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3333333333333333, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4444444444444444, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7777777777777778, 0.625, 'Rank <= 7.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.6666666666666667, 0.75, '  False'),
#  Text(0.6666666666666666, 0.375, 'Age <= 29.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5555555555555556, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7777777777777778, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8888888888888888, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]')]

# %%
#LINEAR REGRESSION
##trainning and testing
from sklearn.model_selection import train_test_split
x_train ,x_test, y_train ,y_test =train_test_split(
    x,y,test_size=0.2,
    random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 #LINEAR REGRESSION
#       2 ##trainning and testing
#       3 from sklearn.model_selection import train_test_split
#       4 x_train ,x_test, y_train ,y_test =train_test_split(
# ----> 5     x,y,test_size=0.2,
#       6     random_state=42
#       7 )
#
# NameError: name 'x' is not defined

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 from sklearn.linear_model import LinearRegression
#       2 model = LinearRegression()
# ----> 3 model.fit(x_train,y_test)
#
# NameError: name 'x_train' is not defined

# %%
model.score(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model.score(x_test,y_test)
#
# NameError: name 'x_test' is not defined
